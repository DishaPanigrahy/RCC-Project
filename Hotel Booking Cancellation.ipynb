# %%
#importing lib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import DataFrame
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\Disha\Desktop\hotel booking.csv")

# %%
print(df)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df = df.drop(['hotel','arrival_date_month','customer_type','reservation_status','name','email','credit_card'], axis =1)

# %%
df = df.drop(['reservation_status_date','phone-number'], axis =1)

# %%
df
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0                 0        342               2015                        27
# 1                 0        737               2015                        27
# 2                 0          7               2015                        27
# 3                 0         13               2015                        27
# 4                 0         14               2015                        27
# ...             ...        ...                ...                       ...
# 119385            0         23               2017                        35
# 119386            0        102               2017                        35
# 119387            0         34               2017                        35
# 119388            0        109               2017                        35
# 119389            0        205               2017                        35
#
# ...

# %%
df = df.drop(['meal','country','market_segment','distribution_channel','reserved_room_type','assigned_room_type','deposit_type'], axis =1)

# %%
df
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0                 0        342               2015                        27
# 1                 0        737               2015                        27
# 2                 0          7               2015                        27
# 3                 0         13               2015                        27
# 4                 0         14               2015                        27
# ...             ...        ...                ...                       ...
# 119385            0         23               2017                        35
# 119386            0        102               2017                        35
# 119387            0         34               2017                        35
# 119388            0        109               2017                        35
# 119389            0        205               2017                        35
#
# ...

# %%
df['agent']=df['agent'].fillna(df['agent'].mean())
df['company']=df['company'].fillna(df['company'].mean())
df['children']=df['children'].fillna(df['children'].mean())

# %%
df
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0                 0        342               2015                        27
# 1                 0        737               2015                        27
# 2                 0          7               2015                        27
# 3                 0         13               2015                        27
# 4                 0         14               2015                        27
# ...             ...        ...                ...                       ...
# 119385            0         23               2017                        35
# 119386            0        102               2017                        35
# 119387            0         34               2017                        35
# 119388            0        109               2017                        35
# 119389            0        205               2017                        35
#
# ...

# %%
df.shape
# Out:
# (119390, 20)

# %%
df.columns
# Out:
# Index(['is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_week_number', 'arrival_date_day_of_month',
#        'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children',
#        'babies', 'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'booking_changes', 'agent', 'company',
#        'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
#        'total_of_special_requests'],
#       dtype='object')

# %%
df.head()
# Out:
#    is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0            0        342               2015                        27
# 1            0        737               2015                        27
# 2            0          7               2015                        27
# 3            0         13               2015                        27
# 4            0         14               2015                        27
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
#
#    adults  children  babies  is_repeated_guest  previous_cancellations  \
# ...

# %%
df.tail()
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 119385            0         23               2017                        35
# 119386            0        102               2017                        35
# 119387            0         34               2017                        35
# 119388            0        109               2017                        35
# 119389            0        205               2017                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# 119388                         31                        2
# 119389                         29                        2
#
#         stays_in_week_nights  adults  children  babies  is_repeated_guest  \
# 119385                     5       2       0.0       0                  0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.isnull().any().any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   is_canceled                     119390 non-null  int64
#  1   lead_time                       119390 non-null  int64
#  2   arrival_date_year               119390 non-null  int64
#  3   arrival_date_week_number        119390 non-null  int64
#  4   arrival_date_day_of_month       119390 non-null  int64
#  5   stays_in_weekend_nights         119390 non-null  int64
#  6   stays_in_week_nights            119390 non-null  int64
#  7   adults                          119390 non-null  int64
#  8   children                        119390 non-null  float64
#  9   babies                          119390 non-null  int64
#  10  is_repeated_guest               119390 non-null  int64
#  11  previous_cancellations          119390 non-null  int64
# ...

# %%
sns.catplot(x = 'is_canceled', data = df, kind = 'count')

# %%
plt.boxplot(df.is_canceled)
Q1 = df.is_canceled.quantile(0.25)
Q3 = df.is_canceled.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.is_canceled >= Q1 - 1.5*IQR) & (df.is_canceled <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.lead_time)
Q1 = df.lead_time.quantile(0.25)
Q3 = df.lead_time.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.lead_time >= Q1 - 1.5*IQR) & (df.lead_time <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.arrival_date_year)
Q1 = df.arrival_date_year.quantile(0.25)
Q3 = df.arrival_date_year.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.arrival_date_year >= Q1 - 1.5*IQR) & (df.arrival_date_year <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.arrival_date_week_number)
Q1 = df.arrival_date_week_number.quantile(0.25)
Q3 = df.arrival_date_week_number.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.arrival_date_week_number >= Q1 - 1.5*IQR) & (df.arrival_date_week_number <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.arrival_date_day_of_month)
Q1 = df.arrival_date_day_of_month.quantile(0.25)
Q3 = df.arrival_date_day_of_month.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.arrival_date_day_of_month >= Q1 - 1.5*IQR) & (df.arrival_date_day_of_month <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.stays_in_weekend_nights)
Q1 = df.stays_in_weekend_nights.quantile(0.25)
Q3 = df.stays_in_weekend_nights.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.stays_in_weekend_nights >= Q1 - 1.5*IQR) & (df.stays_in_weekend_nights <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.stays_in_week_nights)
Q1 = df.stays_in_week_nights.quantile(0.25)
Q3 = df.stays_in_week_nights.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.stays_in_week_nights >= Q1 - 1.5*IQR) & (df.stays_in_week_nights <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.adults)
Q1 = df.adults.quantile(0.25)
Q3 = df.adults.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.adults >= Q1 - 1.5*IQR) & (df.adults <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.children)
Q1 = df.children.quantile(0.25)
Q3 = df.children.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.children >= Q1 - 1.5*IQR) & (df.children <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.babies)
Q1 = df.babies.quantile(0.25)
Q3 = df.babies.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.babies >= Q1 - 1.5*IQR) & (df.babies <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.is_repeated_guest)
Q1 = df.is_repeated_guest.quantile(0.25)
Q3 = df.is_repeated_guest .quantile(0.75)
IQR = Q3 - Q1
df = df[(df.is_repeated_guest >= Q1 - 1.5*IQR) & (df.is_repeated_guest <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.previous_cancellations)
Q1 = df.previous_cancellations.quantile(0.25)
Q3 = df.previous_cancellations.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.previous_cancellations >= Q1 - 1.5*IQR) & (df.previous_cancellations <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.previous_bookings_not_canceled)
Q1 = df.previous_bookings_not_canceled.quantile(0.25)
Q3 = df.previous_bookings_not_canceled.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.previous_bookings_not_canceled >= Q1 - 1.5*IQR) & (df.previous_bookings_not_canceled <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.booking_changes)
Q1 = df.booking_changes.quantile(0.25)
Q3 = df.booking_changes.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.booking_changes >= Q1 - 1.5*IQR) & (df.booking_changes <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.agent)
Q1 = df.agent.quantile(0.25)
Q3 = df.agent.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.agent >= Q1 - 1.5*IQR) & (df.agent <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.company)
Q1 = df.company.quantile(0.25)
Q3 = df.company.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.company >= Q1 - 1.5*IQR) & (df.company <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.days_in_waiting_list)
Q1 = df.days_in_waiting_list.quantile(0.25)
Q3 = df.days_in_waiting_list.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.days_in_waiting_list >= Q1 - 1.5*IQR) & (df.days_in_waiting_list <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.adr)
Q1 = df.adr.quantile(0.25)
Q3 = df.adr.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.adr >= Q1 - 1.5*IQR) & (df.adr <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.required_car_parking_spaces)
Q1 = df.required_car_parking_spaces.quantile(0.25)
Q3 = df.required_car_parking_spaces.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.required_car_parking_spaces >= Q1 - 1.5*IQR) & (df.required_car_parking_spaces <= Q3 + 1.5*IQR)]

# %%
plt.boxplot(df.total_of_special_requests)
Q1 = df.total_of_special_requests.quantile(0.25)
Q3 = df.total_of_special_requests.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.total_of_special_requests >= Q1 - 1.5*IQR) & (df.total_of_special_requests <= Q3 + 1.5*IQR)]

# %%
plt.figure(figsize = (20,20))
sns.heatmap(df.corr(), color = "k", annot = True)
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                                 is_canceled  lead_time  arrival_date_year  \
# is_canceled                        1.000000   0.235287           0.118591
# lead_time                          0.235287   1.000000           0.126520
# arrival_date_year                  0.118591   0.126520           1.000000
# arrival_date_week_number          -0.022529   0.092249          -0.542035
# arrival_date_day_of_month          0.007560   0.005315          -0.013645
# stays_in_weekend_nights           -0.035057   0.074054          -0.015951
# stays_in_week_nights               0.005826   0.201082           0.029763
# adults                                  NaN        NaN                NaN
# children                                NaN        NaN                NaN
# babies                                  NaN        NaN                NaN
# is_repeated_guest                       NaN        NaN                NaN
# previous_cancellations                  NaN        NaN                NaN
# ...

# %%
df.hist(bins = 20, figsize = (25,25))
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
Norm_scale = ['is_canceled', 'lead_time', 'arrival_date_year',
       'arrival_date_week_number', 'arrival_date_day_of_month',
       'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children',
       'babies', 'is_repeated_guest', 'previous_cancellations',
       'previous_bookings_not_canceled', 'booking_changes', 'agent', 'company',
       'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
       'total_of_special_requests']

# %%
df[Norm_scale] = scaler.fit_transform(df[Norm_scale])

# %%
df
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 4               0.0   0.037534                0.0                  0.500000
# 5               0.0   0.037534                0.0                  0.500000
# 6               0.0   0.000000                0.0                  0.500000
# 7               0.0   0.024129                0.0                  0.500000
# 8               1.0   0.227882                0.0                  0.500000
# ...             ...        ...                ...                       ...
# 119381          0.0   0.504021                1.0                  0.653846
# 119383          0.0   0.439678                1.0                  0.653846
# 119384          0.0   0.056300                1.0                  0.653846
# 119385          0.0   0.061662                1.0                  0.653846
# 119388          0.0   0.292225                1.0                  0.653846
#
# ...

# %% [markdown]
# CLASSIFICATION

# %% [markdown]
# RFC

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
Y = df['is_canceled']
X = df[['lead_time', 'arrival_date_year',
       'arrival_date_week_number', 'arrival_date_day_of_month',
       'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children',
       'babies', 'is_repeated_guest', 'previous_cancellations',
       'previous_bookings_not_canceled', 'booking_changes', 'agent', 'company',
       'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
       'total_of_special_requests']]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn import metrics

# %%
X_train, X_test , y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(k_neighbors = 4)
X,Y = sm.fit_resample(X,Y)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rfc_pred = rfc.predict(X_test)

# %%
print("Accuracy : %.2f%%" % (accuracy_score(rfc_pred,y_test)*100.0))
# Out:
# Accuracy : 83.21%

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
Y = df['is_canceled']
X = df[['lead_time', 'arrival_date_year',
       'arrival_date_week_number', 'arrival_date_day_of_month',
       'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children',
       'babies', 'is_repeated_guest', 'previous_cancellations',
       'previous_bookings_not_canceled', 'booking_changes', 'agent', 'company',
       'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
       'total_of_special_requests']]

# %%
sm = SMOTE(k_neighbors = 4)
X,Y = sm.fit_resample(X,Y)

# %%
X_train, X_test , y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
knn = KNeighborsClassifier(n_neighbors = 3)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn_pred = knn.predict(X_test)

# %%
print("Accuracy", metrics.accuracy_score(y_test, knn_pred)*100)
# Out:
# Accuracy 78.9481983757786

# %% [markdown]
# DCT

# %%
from sklearn import preprocessing 
from sklearn import tree

# %%
Y = df['is_canceled']
X = df[['lead_time', 'arrival_date_year',
       'arrival_date_week_number', 'arrival_date_day_of_month',
       'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children',
       'babies', 'is_repeated_guest', 'previous_cancellations',
       'previous_bookings_not_canceled', 'booking_changes', 'agent', 'company',
       'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
       'total_of_special_requests']]

# %%
sm = SMOTE(k_neighbors = 4)
X,Y = sm.fit_resample(X,Y)

# %%
X_train, X_test , y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)
dt = tree.DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred = dt.predict(X_test)
print("Accuracy", metrics.accuracy_score(y_test, dt_pred)*100)
# Out:
# Accuracy 81.25049278561855

# %% [markdown]
# PREDICTION

# %%
r, c = 19, 19
l1 = [[0 for x in range (c)] for y in range(r)]

lead_time = float(input("lead_time(0-737) :"))
l1[0][0] = lead_time
l1[1][0] = lead_time

arrival_date_year = float(input("arrival_date_year(2015-2017) :"))
l1[0][1] = arrival_date_year
l1[1][1] = arrival_date_year

arrival_date_week_number = float(input("arrival_date_week_number(1-53) :"))
l1[0][2] = arrival_date_week_number
l1[1][2] = arrival_date_week_number

stays_in_weekend_nights = float(input("stays_in_weekend_nights(1-31) :"))
l1[0][3] = stays_in_weekend_nights
l1[1][3] = stays_in_weekend_nights

stays_in_week_nights = float(input("stays_in_week_nights(0-19) :"))
l1[0][4] = stays_in_week_nights
l1[1][4] = stays_in_week_nights

adults = float(input("adults(0-50) :"))
l1[0][5] = adults
l1[1][5] = adults

children = float(input("children(0-55) :"))
l1[0][6] = children
l1[1][6] = children

babies = float(input("babies(0-3) :"))
l1[0][7] = babies
l1[1][7] = babies

is_repeated_guest = float(input("is_repeated_guest(0-1) :"))
l1[0][8] = is_repeated_guest
l1[1][8] = is_repeated_guest

previous_cancellations = float(input("previous_cancellations(0-26) :"))
l1[0][9] = previous_cancellations
l1[1][9] = previous_cancellations

previous_booking_not_canceled = float(input("previous_booking_not_canceled(1-72) :"))
l1[0][10] = previous_booking_not_canceled
l1[1][10] = previous_booking_not_canceled

booking_changes = float(input("booking_changes(0-21) :"))
l1[0][11] = booking_changes
l1[1][11] = booking_changes

agent = float(input("agent(7-423) :"))
l1[0][12] = agent
l1[1][12] = agent

company = float(input("company(6-543) :"))
l1[0][13] = company
l1[1][13] = company

days_in_waiting_list = float(input("days_in_waiting_list(0-391) :"))
l1[0][14] = days_in_waiting_list
l1[1][14] = days_in_waiting_list

adr = float(input("adr(-6.38-5400) :"))
l1[0][15] = adr
l1[1][15] = adr

required_car_parking_spaces = float(input("required_car_parking_spaces(0-8) :"))
l1[0][16] = required_car_parking_spaces
l1[1][16] = required_car_parking_spaces

total_of_special_request = float(input("total_of_special_request(0-5) :"))
l1[0][17] = total_of_special_request
l1[1][17] = total_of_special_request

# %%
rfc_pred = rfc.predict(l1)
print('Booking Cancelled')
print(float(dt_pred[0]))

# %% [markdown]
# END
